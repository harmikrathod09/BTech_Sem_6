# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <center>
#     <b>
#         <h3>Machine Learning and Deep Learning Fundamentals and Applications - 2501CS633</h3>
#         <h3>Lab - 13</h3>
#         <h3>Rathod Harmik Kamleshbhai - 24010101680</h3>
#     </b>
# </center>

# %% [markdown]
# ## Section 1: PyTorch

# %% [markdown]
# ## Import Torch

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ### Task 1: GPU/Device Agnostic Code
# **Goal:** Write code that runs on CPU, CUDA, or MPS (Mac) automatically.

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f'Using device: {device}')


sample_input = torch.randn(1, 10).to(device)
type(sample_input)
# Out:
# Using device: cuda
# torch.Tensor

# %%
sample_input
# Out:
# tensor([[-0.5284, -0.4614, -1.4719, -0.2356,  0.6903, -1.6530,  0.2846, -0.6896,
#           0.7058,  0.2269]], device='cuda:0')

# %% [markdown]
# ## Section 2: MNIST Project
# Step 1: What is MNIST & Downloading Data
#
# Concept: MNIST is the "Hello World" of Machine Learning. It contains 70,000 images of handwritten digits (0-9).
#
# The Goal: Teach the computer to look at a grid of pixels and say "That is a 7".
#
# The Data: Each image is grayscale and exactly 28×28

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

# transform=ToTensor() converts the image (0-255) to a Torch Tensor (0.0-1.0)

# %%
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %% [markdown]
# ## Visualizing One Image & Understanding Shapes

# %%
len(training_data)
# Out:
# 60000

# %%
len(test_data)
# Out:
# 10000

# %%
img, label = training_data[0]

# %%
img.shape
# Out:
# torch.Size([1, 28, 28])

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## Display one Image in MatplotLib

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img.squeeze(), cmap="gray")
plt.title(f"This is a number {label}")
plt.show()

# %% [markdown]
# # Calculation for the Input Layer

# %% [markdown]
# Concept: We are building a Linear (Feed-Forward) Network,
#
# A Linear Layer consists of neurons in a single vertical line.
#
# Our image is a square grid (28×28).
#
# The Division: We must "cut" the image row by row and stack them into one long line.
#
# The Calculation:
#
# Height×Width=Total Input Features
# 28×28=784
# So, our Input Layer must have 784 neurons.

# %%
img, label = training_data[1]

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## The Architecture (1 Input, 1 Hidden, 1 Output
# The Concept: We will build the simplest standard network.
#
# Input Layer (784): Receives the pixels.
#
# Hidden Layer (128): The "brain" that learns shapes (loops, lines). We pick 128 because it's enough to learn but not too big.
#
# Output Layer (10): The final decision. We have 10 digits (0-9), so we need 10 output scores.

# %%
import torch.nn as nn

class SimpleNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        
        self.layers = nn.Sequential(
            nn.Linear(784, 128), 
            nn.ReLU(),# Activation 
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.layers(x)
        return logits

model = SimpleNet()
print(model)
# Out:
# SimpleNet(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layers): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Understanding Batch Size (The Stack)
#
# The Concept: Think of the model like a teacher grading exams.
#
# Batch Size = 1: The teacher grades 1 exam, updates the grade book, then picks up the next exam. (Too slow).
#
# Batch Size = 64: The teacher picks up a stack of 64 exams, grades them all at once, and updates the grade book one time for the whole stack. (Much faster).
#
# We use DataLoader to create these "stacks" for us.

# %%
from torch.utils.data import DataLoader

# Create stacks
train_loader = DataLoader(training_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=True)

print(len(train_loader),"--",len(test_loader))
# Out:
# 938 -- 157

# %% [markdown]
# ## The Training Loop

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
def train():
    model.train()
    
    # Epoch Loop - Train for multiple epochs
    num_epochs = 5
    
    for epoch in range(num_epochs):
        print(f"\n--- Epoch {epoch + 1}/{num_epochs} ---")
        
        for batch_No, (data, target) in enumerate(train_loader):
            
            output = model(data)
            
            loss = loss_fn(output, target)
            
            # Backpropagation
            optimizer.zero_grad()  # Clear old calculations
            loss.backward()        # Calculate gradients
            optimizer.step()       # Update weights
            
            if batch_No % 100 == 0:
                print(f"Batch {batch_No}: Loss = {loss.item():.4f}")
        
        print(f"Epoch {epoch + 1} completed!")

# Run training

# %%
train()
# Out:
# --- Epoch 1/5 ---
# Batch 0: Loss = 2.2953
# Batch 100: Loss = 0.4822
# Batch 200: Loss = 0.5985
# Batch 300: Loss = 0.2472
# Batch 400: Loss = 0.3463
# Batch 500: Loss = 0.2362
# Batch 600: Loss = 0.1900
# Batch 700: Loss = 0.2609
# Batch 800: Loss = 0.2171
# Batch 900: Loss = 0.2784
# Epoch 1 completed!
#
# --- Epoch 2/5 ---
# Batch 0: Loss = 0.3045
# Batch 100: Loss = 0.2113
# Batch 200: Loss = 0.2661
# Batch 300: Loss = 0.1706
# Batch 400: Loss = 0.0547
# Batch 500: Loss = 0.1118
# Batch 600: Loss = 0.1438
# Batch 700: Loss = 0.1112
# Batch 800: Loss = 0.1352
# Batch 900: Loss = 0.1198
# Epoch 2 completed!
#
# --- Epoch 3/5 ---
# Batch 0: Loss = 0.1229
# Batch 100: Loss = 0.0800
# Batch 200: Loss = 0.1282
# Batch 300: Loss = 0.1371
# Batch 400: Loss = 0.1605
# Batch 500: Loss = 0.0448
# Batch 600: Loss = 0.1036
# Batch 700: Loss = 0.0499
# Batch 800: Loss = 0.2193
# Batch 900: Loss = 0.0547
# Epoch 3 completed!
#
# --- Epoch 4/5 ---
# Batch 0: Loss = 0.0861
# Batch 100: Loss = 0.0799
# Batch 200: Loss = 0.0923
# Batch 300: Loss = 0.0762
# Batch 400: Loss = 0.1018
# Batch 500: Loss = 0.1183
# Batch 600: Loss = 0.0776
# Batch 700: Loss = 0.0957
# Batch 800: Loss = 0.0916
# Batch 900: Loss = 0.0557
# Epoch 4 completed!
#
# --- Epoch 5/5 ---
# Batch 0: Loss = 0.0338
# Batch 100: Loss = 0.0937
# Batch 200: Loss = 0.1253
# Batch 300: Loss = 0.0589
# Batch 400: Loss = 0.0571
# Batch 500: Loss = 0.0337
# Batch 600: Loss = 0.0843
# Batch 700: Loss = 0.0218
# Batch 800: Loss = 0.0055
# Batch 900: Loss = 0.0730
# Epoch 5 completed!

# %%
def test():
    model.eval() 
    correct = 0
    
    with torch.no_grad(): 
        for data, target in test_loader:
            output = model(data)
            
            prediction = output.argmax(dim=1) 
            
            correct += (prediction == target).sum().item()

    accuracy = correct / len(test_loader.dataset)
    print(f"Test Accuracy: {accuracy:.1%}")

test()
# Out:
# Test Accuracy: 97.6%

# %%
for name, prams in model.named_parameters():
    print(f"{name} | {prams.shape}")
# Out:
# layers.0.weight | torch.Size([128, 784])
# layers.0.bias | torch.Size([128])
# layers.2.weight | torch.Size([10, 128])
# layers.2.bias | torch.Size([10])

# %%
def predict_image(index):
    model.eval()
    img, label = test_data[index]
    
    input_tensor = img.unsqueeze(0)
    with torch.no_grad():
        logits = model(input_tensor)
        predicted_label = logits.argmax(dim=1).item()

    plt.imshow(img.squeeze(0), cmap="gray")
    plt.title(f"Actual:{label} | Predicted:{predicted_label}")
    plt.axis("off")
    plt.show()

# %%
predict_image(123)
