# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <center>
#     <b>
#         <h3>Machine Learning and Deep Learning Fundamentals and Applications - 2501CS633</h3>
#         <h3>Lab - 5</h3>
#         <h3>Rathod Harmik Kamleshbhai - 24010101680</h3>
#     </b>
# </center>

# %% [markdown]
# # SVR

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read World bank CSV

# %%
df = pd.read_csv('WorldBank.csv')

# %%
df
# Out:
#      Country Name Country Code  \
# 0           India          IND
# 1           India          IND
# 2           India          IND
# 3           India          IND
# 4           India          IND
# ...           ...          ...
# 1435        India          IND
# 1436        India          IND
# 1437        India          IND
# 1438        India          IND
# 1439        India          IND
#
#                                          Indicator Name        Indicator Code  \
# 0                       Export value index (2000 = 100)     TX.VAL.MRCH.XD.WD
# 1     Insurance and financial services (% of commerc...     TX.VAL.INSF.ZS.WT
# 2     Merchandise imports by the reporting economy, ...     TM.VAL.MRCH.RS.ZS
# 3               Food imports (% of merchandise imports)     TM.VAL.FOOD.ZS.UN
# 4     Share of tariff lines with international peaks...     TM.TAX.MRCH.IP.ZS
# ...                                                 ...                   ...
# 1435  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 1436             Net capital account (BoP, current US$)        BN.TRF.KOGT.CD
# 1437        Travel services (% of service imports, BoP)        BM.GSR.TRVL.ZS
# 1438                    Cereal production (metric tons)        AG.PRD.CREL.MT
# 1439                       Arable land (% of land area)        AG.LND.ARBL.ZS
#
#           1960          1961          1962          1963          1964  \
# 0          NaN           NaN           NaN           NaN           NaN
# 1          NaN           NaN           NaN           NaN           NaN
# 2     4.983551  6.488050e+00  1.012461e+01  9.451370e+00  1.052948e+01
# 3          NaN           NaN  1.708001e+01  1.519791e+01  1.686304e+01
# 4          NaN           NaN           NaN           NaN           NaN
# ...        ...           ...           ...           ...           ...
# 1435       NaN           NaN           NaN           NaN           NaN
# 1436       NaN           NaN           NaN           NaN           NaN
# 1437       NaN           NaN           NaN           NaN           NaN
# 1438       NaN  8.737650e+07  8.725755e+07  9.037301e+07  9.370600e+07
# 1439       NaN  5.240365e+01  5.270433e+01  5.296332e+01  5.305144e+01
#
#               1965  ...          2011          2012          2013  \
# 0              NaN  ...  7.147485e+02  7.004085e+02  7.429281e+02
# 1              NaN  ...  6.403614e+00  5.246771e+00  5.729495e+00
# 2     1.089112e+01  ...  7.550664e-01  2.738416e-01  4.409538e-01
# 3     2.200813e+01  ...  3.741041e+00  4.048246e+00  3.895215e+00
# 4              NaN  ...  8.434346e+00  8.641136e+00  8.576307e+00
# ...            ...  ...           ...           ...           ...
# 1435           NaN  ...  2.002065e+00  1.312934e+00  1.516276e+00
# 1436           NaN  ...  6.791581e+07 -5.972328e+08  9.618297e+08
# 1437           NaN  ...  1.761773e+01  1.544257e+01  1.475397e+01
# 1438  7.969950e+07  ...  2.878600e+08  2.932900e+08  2.949095e+08
# 1439  5.321422e+01  ...  5.279817e+01  5.265254e+01  5.261756e+01
#
#               2014          2015          2016          2017          2018  \
# 0     7.614417e+02  6.322694e+02  6.242250e+02  7.061028e+02  7.663608e+02
# 1     5.060904e+00  4.706801e+00  4.471147e+00  3.760466e+00  3.921611e+00
# 2     1.514439e+00  2.228351e+00  2.270593e+00  1.770314e+00  5.354193e-01
# 3     4.458509e+00  5.758038e+00  6.505293e+00  6.137617e+00  4.156488e+00
# 4              NaN  5.802677e+00  7.707811e+00  8.288774e+00  9.111423e+00
# ...            ...           ...           ...           ...           ...
# 1435  1.695659e+00  2.092116e+00  1.937363e+00  1.506588e+00  1.552336e+00
# 1436 -7.433364e+07  3.706943e+07  1.368359e+08  3.731153e+07 -1.231007e+08
# 1437  1.799216e+01  1.795378e+01  1.707263e+01  1.686302e+01  1.716750e+01
# 1438  2.960100e+08  2.843330e+08  2.978500e+08  3.136100e+08           NaN
# 1439  5.262462e+01  5.262462e+01  5.262462e+01           NaN           NaN
#
#               2019  2020
# 0              NaN   NaN
# 1     3.438072e+00   NaN
# 2              NaN   NaN
# 3     4.248261e+00   NaN
# 4              NaN   NaN
# ...            ...   ...
# 1435  1.760283e+00   NaN
# 1436 -1.155591e+09   NaN
# 1437  1.755462e+01   NaN
# 1438           NaN   NaN
# 1439           NaN   NaN
#
# [1440 rows x 65 columns]

# %% [markdown]
# # Perform conditional selection to find - Population ages 15-64 (% of total population)

# %%
data = df[df["Indicator Name"] == "Population ages 15-64 (% of total population)"]
data
# Out:
#   Country Name Country Code                                 Indicator Name  \
# 9        India          IND  Population ages 15-64 (% of total population)
#
#       Indicator Code      1960       1961       1962       1963       1964  \
# 9  SP.POP.1564.TO.ZS  56.49748  56.177532  55.807455  55.461664  55.248939
#
#         1965  ...       2011       2012       2013      2014       2015  \
# 9  55.211351  ...  64.429404  64.805519  65.208489  65.59598  65.944164
#
#         2016       2017       2018       2019  2020
# 9  66.274262  66.538187  66.766743  67.003811   NaN
#
# [1 rows x 65 columns]

# %% [markdown]
# # Divide the data into input and output

# %%
x = np.arange(1960, 2020).reshape(-1, 1)
x
# Out:
# array([[1960],
#        [1961],
#        [1962],
#        [1963],
#        [1964],
#        [1965],
#        [1966],
#        [1967],
#        [1968],
#        [1969],
#        [1970],
#        [1971],
#        [1972],
#        [1973],
#        [1974],
#        [1975],
#        [1976],
#        [1977],
#        [1978],
#        [1979],
#        [1980],
#        [1981],
#        [1982],
#        [1983],
#        [1984],
#        [1985],
#        [1986],
#        [1987],
#        [1988],
#        [1989],
#        [1990],
#        [1991],
#        [1992],
#        [1993],
#        [1994],
#        [1995],
#        [1996],
#        [1997],
#        [1998],
#        [1999],
#        [2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018],
#        [2019]])

# %%
y = data.values[0][4:-1:].reshape(-1, 1)
y
# Out:
# array([[56.49748004],
#        [56.17753236],
#        [55.80745463],
#        [55.46166361],
#        [55.24893881],
#        [55.21135053],
#        [55.09090078],
#        [55.15534672],
#        [55.34507283],
#        [55.57014408],
#        [55.78194745],
#        [55.85676846],
#        [55.95268174],
#        [56.07247186],
#        [56.23447551],
#        [56.44405309],
#        [56.49722595],
#        [56.62068516],
#        [56.78900152],
#        [56.9691436],
#        [57.1425581],
#        [57.18105454],
#        [57.22630775],
#        [57.28875038],
#        [57.39054366],
#        [57.54142108],
#        [57.55350984],
#        [57.6545119],
#        [57.81875323],
#        [58.01501187],
#        [58.22990246],
#        [58.37403848],
#        [58.5472698],
#        [58.75605047],
#        [59.012126],
#        [59.31657719],
#        [59.56507329],
#        [59.8572303],
#        [60.18600058],
#        [60.53971518],
#        [60.90862046],
#        [61.18898716],
#        [61.4993847],
#        [61.83084479],
#        [62.173897],
#        [62.52276485],
#        [62.80842981],
#        [63.10261029],
#        [63.40924784],
#        [63.74196691],
#        [64.10821053],
#        [64.429404],
#        [64.80551944],
#        [65.20848906],
#        [65.5959799],
#        [65.94416405],
#        [66.27426247],
#        [66.53818711],
#        [66.7667425],
#        [67.00381119]], dtype=object)

# %%
# Out:
# array([[56.49748004],
#        [56.17753236],
#        [55.80745463],
#        [55.46166361],
#        [55.24893881],
#        [55.21135053],
#        [55.09090078],
#        [55.15534672],
#        [55.34507283],
#        [55.57014408],
#        [55.78194745],
#        [55.85676846],
#        [55.95268174],
#        [56.07247186],
#        [56.23447551],
#        [56.44405309],
#        [56.49722595],
#        [56.62068516],
#        [56.78900152],
#        [56.9691436],
#        [57.1425581],
#        [57.18105454],
#        [57.22630775],
#        [57.28875038],
#        [57.39054366],
#        [57.54142108],
#        [57.55350984],
#        [57.6545119],
#        [57.81875323],
#        [58.01501187],
#        [58.22990246],
#        [58.37403848],
#        [58.5472698],
#        [58.75605047],
#        [59.012126],
#        [59.31657719],
#        [59.56507329],
#        [59.8572303],
#        [60.18600058],
#        [60.53971518],
#        [60.90862046],
#        [61.18898716],
#        [61.4993847],
#        [61.83084479],
#        [62.173897],
#        [62.52276485],
#        [62.80842981],
#        [63.10261029],
#        [63.40924784],
#        [63.74196691],
#        [64.10821053],
#        [64.429404],
#        [64.80551944],
#        [65.20848906],
#        [65.5959799],
#        [65.94416405],
#        [66.27426247],
#        [66.53818711],
#        [66.7667425],
#        [67.00381119]], dtype=object)

# %% [markdown]
# # Plot scatter plot of Population ages 15-64 (% of total population)

# %%
plt.scatter(x, y)
plt.xlabel("Year")
plt.ylabel("Population ages 15-64 (% of total population)")
# Out:
# Text(0, 0.5, 'Population ages 15-64 (% of total population)')

# %% [markdown]
# # Feature Scaling (Mandatory for SVR)**
# SVR is highly sensitive to the range of data points. If we don't scale (normalize) the data, the model will fail to find the correct hyperplane.

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc_x = StandardScaler()
sc_y = StandardScaler()

x_scaled = sc_x.fit_transform(x)
y_scaled = sc_y.fit_transform(y)

print("Scaling Complete")
# Out:
# Scaling Complete

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_scaled, test_size=0.2, random_state=42)

# %%
x_train
# Out:
# array([[ 0.08661457],
#        [-1.53019075],
#        [ 1.29921857],
#        [-0.72178809],
#        [-1.24147552],
#        [-1.35696161],
#        [ 0.606302  ],
#        [-1.47244771],
#        [ 0.77953114],
#        [-0.606302  ],
#        [ 0.25984371],
#        [ 1.64567685],
#        [-0.25984371],
#        [ 1.53019075],
#        [-0.83727419],
#        [-0.14435762],
#        [-1.18373247],
#        [ 0.02887152],
#        [-0.20210067],
#        [-0.77953114],
#        [-0.31758676],
#        [ 1.47244771],
#        [-1.06824638],
#        [ 0.14435762],
#        [ 1.35696161],
#        [ 0.66404504],
#        [ 0.43307286],
#        [-0.02887152],
#        [ 0.83727419],
#        [-1.64567685],
#        [-0.4908159 ],
#        [-1.5879338 ],
#        [ 1.01050333],
#        [ 0.54855895],
#        [ 0.31758676],
#        [-0.37532981],
#        [ 1.12598942],
#        [-1.12598942],
#        [-0.43307286],
#        [-0.66404504],
#        [ 1.7034199 ],
#        [-0.54855895],
#        [-1.29921857],
#        [ 0.72178809],
#        [-0.89501723],
#        [-0.08661457],
#        [ 1.24147552],
#        [ 0.4908159 ]])

# %% [markdown]
# # Fitting SVR on 3 Different Kernel on dataset

# %%
from sklearn.svm import SVR

# %%
model_rbf = SVR()

# %%
model_rbf.fit(x_train, y_train.ravel())
# Out:
# SVR()

# %%
x_grid = np.arange(min(x_test), max(x_test), 0.1)
x_grid = x_grid.reshape((len(x_grid), 1))

plt.scatter(x, y, color='red', label='Real Data')

plt.plot(sc_x.inverse_transform(x_grid), sc_y.inverse_transform(model_rbf.predict(x_grid).reshape(-1, 1)), color='blue', label='RBF Model')

plt.title('SVR Regression Results')
plt.xlabel('Year / feachers')
plt.ylabel('population / features')
plt.legend()
plt.show()
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_19152\3655485859.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x_test), max(x_test), 0.1)

# %% [markdown]
# # Predict the x_test using 3 Kernel

# %%
model_rbf.score(x_train,y_train)
# Out:
# 0.9953867997446317

# %%
model_rbf.score(x_test,y_test)
# Out:
# 0.9963995902170167

# %%
y_pred_rbf = model_rbf.predict(x_test)

# %%
x_test
# Out:
# array([[-1.7034199 ],
#        [-1.41470466],
#        [ 0.37532981],
#        [ 0.89501723],
#        [-0.95276028],
#        [ 1.41470466],
#        [ 0.20210067],
#        [ 1.06824638],
#        [-1.01050333],
#        [ 1.5879338 ],
#        [ 0.95276028],
#        [ 1.18373247]])

# %% [markdown]
# # Visualising the  results

# %%
svr_rbf = SVR(kernel='rbf')
svr_lin = SVR(kernel='linear')
svr_poly = SVR(kernel='poly')

svr_rbf.fit(x_train, y_train.ravel())
svr_lin.fit(x_train, y_train.ravel())
svr_poly.fit(x_train, y_train.ravel())

plt.figure(figsize=(12,8))
plt.scatter(x, y, color='orange', label='Data')

plt.plot(sc_x.inverse_transform(x_grid), sc_y.inverse_transform(svr_rbf.predict(x_grid).reshape(-1, 1)), color='green', label='RBF model')
plt.plot(sc_x.inverse_transform(x_grid), sc_y.inverse_transform(svr_lin.predict(x_grid).reshape(-1, 1)), color='blue', label='Linear model')
plt.plot(sc_x.inverse_transform(x_grid), sc_y.inverse_transform(svr_poly.predict(x_grid).reshape(-1, 1)), color='cyan', label='Polynomial model')


plt.title('Support Vector Regression: Kernel Comparison')
plt.xlabel('data')
plt.ylabel('target')
plt.legend()
plt.show()

# %% [markdown]
# ### **Student Activity : Prediction**
# **Task:** Predict the value for the Year **2025** (or value 6.5 in the demo data).
# Remember: You must transform the input before predicting, and inverse transform the output.

# %%
value_to_predict = [[2025]]
value_scaled = sc_x.transform(value_to_predict)
predict_scaled = model_rbf.predict(value_scaled)
predict = sc_y.inverse_transform(predict_scaled.reshape(-1, 1))
predict
# Out:
# array([[65.82072271]])
