# %% [markdown]
# # Lab 11

# %% [markdown]
# ## Section 1: PyTorch

# %% [markdown]
# ## Import Torch

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ### Task 1: GPU/Device Agnostic Code
# **Goal:** Write code that runs on CPU, CUDA, or MPS (Mac) automatically.

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f'Using device: {device}')


sample_input = torch.randn(1, 10).to(device)
type(sample_input)
# Out:
# Using device: cuda
# torch.Tensor

# %% [markdown]
# ## Section 2: MNIST Project
# Step 1: What is MNIST & Downloading Data
#
# Concept: MNIST is the "Hello World" of Machine Learning. It contains 70,000 images of handwritten digits (0-9).
#
# The Goal: Teach the computer to look at a grid of pixels and say "That is a 7".
#
# The Data: Each image is grayscale and exactly 28×28

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

# transform=ToTensor() converts the image (0-255) to a Torch Tensor (0.0-1.0)
# Out:
# 100%|██████████| 9.91M/9.91M [00:02<00:00, 4.09MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 127kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.24MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 13.7MB/s]

# %%
# Do for Testing
testing_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %% [markdown]
# ## Visualizing One Image & Understanding Shapes

# %%
len(training_data)
# Out:
# 60000

# %%
len(testing_data)
# Out:
# 10000

# %%
img,target = training_data[-1]

# %%
img.shape
# Out:
# torch.Size([1, 28, 28])

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## Display one Image in MatplotLib

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img.squeeze(),cmap="gray")
plt.title(f"Image of target {target}")
plt.show()

# %% [markdown]
# # Calculation for the Input Layer

# %% [markdown]
# Concept: We are building a Linear (Feed-Forward) Network,
#
# A Linear Layer consists of neurons in a single vertical line.
#
# Our image is a square grid (28×28).
#
# The Division: We must "cut" the image row by row and stack them into one long line.
#
# The Calculation:
#
# Height×Width=Total Input Features
# 28×28=784
# So, our Input Layer must have 784 neurons.

# %%
img, label = training_data[1]

# %%
img.squeeze().shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## The Architecture (1 Input, 1 Hidden, 1 Output
# The Concept: We will build the simplest standard network.
#
# Input Layer (784): Receives the pixels.
#
# Hidden Layer (128): The "brain" that learns shapes (loops, lines). We pick 128 because it's enough to learn but not too big.
#
# Output Layer (10): The final decision. We have 10 digits (0-9), so we need 10 output scores.

# %%
class SimpleNet(nn.Module):
  def __init__(self):
    super().__init__()
    self.flatten = nn.Flatten()

    self.layers=nn.Sequential(
        nn.Linear(784, 128),
        nn.ReLU(),
        nn.Linear(128, 10)
    )

  def forward(self, x):
    x = self.flatten(x)
    logits = self.layers(x)
    return logits

model = SimpleNet()
print(model)
# Out:
# SimpleNet(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layers): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Understanding Batch Size (The Stack)
#
# The Concept: Think of the model like a teacher grading exams.
#
# Batch Size = 1: The teacher grades 1 exam, updates the grade book, then picks up the next exam. (Too slow).
#
# Batch Size = 64: The teacher picks up a stack of 64 exams, grades them all at once, and updates the grade book one time for the whole stack. (Much faster).
#
# We use DataLoader to create these "stacks" for us.

# %%
from torch.utils.data import DataLoader

# Create stacks
train_loader = DataLoader(training_data, batch_size=32, shuffle=True)
# do for Test_data
test_loader = DataLoader(testing_data, batch_size=32, shuffle=True)

print(len(train_loader),"--",len(test_loader))
# Out:
# 1875 -- 313

# %% [markdown]
# ## The Training Loop

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
def train():
  model.train()
  for i in range(5):
    print(f"---------------Eppoch {i}-----------------")
    for batch, (data, target) in enumerate(train_loader):
      output=model(data)
      loss=loss_fn(output,target)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      if batch%100==0: print(f"Batch {batch} Loss {loss.item()}")

# %%
train()
# Out:
# Eppoch 0
# Batch 0 Loss 0.08724815398454666
# Batch 100 Loss 0.017727168276906013
# Batch 200 Loss 0.06431908160448074
# Batch 300 Loss 0.13938109576702118
# Batch 400 Loss 0.006801091134548187
# Batch 500 Loss 0.042761314660310745
# Batch 600 Loss 0.0310063399374485
# Batch 700 Loss 0.00831096712499857
# Batch 800 Loss 0.12278429418802261
# Batch 900 Loss 0.01524099987000227
# Batch 1000 Loss 0.002109481720253825
# Batch 1100 Loss 0.06704418361186981
# Batch 1200 Loss 0.03315434977412224
# Batch 1300 Loss 0.09941297024488449
# Batch 1400 Loss 0.02551586925983429
# Batch 1500 Loss 0.008753000758588314
# Batch 1600 Loss 0.001984428847208619
# Batch 1700 Loss 0.013807354494929314
# Batch 1800 Loss 0.0036184031050652266
# Eppoch 1
# Batch 0 Loss 0.0019491040147840977
# Batch 100 Loss 0.0055489265359938145
# Batch 200 Loss 0.009892485104501247
# Batch 300 Loss 0.059685129672288895
# Batch 400 Loss 0.0259274672716856
# Batch 500 Loss 0.02072117291390896
# Batch 600 Loss 0.030417321249842644
# Batch 700 Loss 0.003516934346407652
# Batch 800 Loss 0.08696841448545456
# Batch 900 Loss 0.0049669090658426285
# Batch 1000 Loss 0.011816706508398056
# Batch 1100 Loss 0.07788336277008057
# Batch 1200 Loss 0.0030025853775441647
# Batch 1300 Loss 0.08844210207462311
# Batch 1400 Loss 0.05211354047060013
# Batch 1500 Loss 0.009257832542061806
# Batch 1600 Loss 0.005975362379103899
# Batch 1700 Loss 0.04404228925704956
# Batch 1800 Loss 0.15655434131622314
# Eppoch 2
# Batch 0 Loss 0.012379739433526993
# Batch 100 Loss 0.012202475219964981
# Batch 200 Loss 0.051205165684223175
# Batch 300 Loss 0.006583751179277897
# Batch 400 Loss 0.005123505834490061
# Batch 500 Loss 0.006177842151373625
# Batch 600 Loss 0.08520805090665817
# Batch 700 Loss 0.012826771475374699
# Batch 800 Loss 0.013062875717878342
# Batch 900 Loss 0.011287644505500793
# Batch 1000 Loss 0.009927377104759216
# Batch 1100 Loss 0.046658482402563095
# Batch 1200 Loss 0.004416154697537422
# Batch 1300 Loss 0.004052877891808748
# Batch 1400 Loss 0.014014375396072865
# Batch 1500 Loss 0.015143721364438534
# Batch 1600 Loss 0.08119365572929382
# Batch 1700 Loss 0.008143370971083641
# Batch 1800 Loss 0.012429840862751007
# Eppoch 3
# Batch 0 Loss 0.0009545531356707215
# Batch 100 Loss 0.009015185758471489
# Batch 200 Loss 0.019851766526699066
# Batch 300 Loss 0.002130431355908513
# Batch 400 Loss 0.0009617813630029559
# Batch 500 Loss 0.07930934429168701
# Batch 600 Loss 0.1107586920261383
# Batch 700 Loss 0.05587098002433777
# Batch 800 Loss 0.06164040043950081
# Batch 900 Loss 0.004011121112853289
# Batch 1000 Loss 0.012490816414356232
# Batch 1100 Loss 0.004373501054942608
# Batch 1200 Loss 0.0034756031818687916
# Batch 1300 Loss 0.0034897804725915194
# Batch 1400 Loss 0.052031010389328
# Batch 1500 Loss 0.0033078929409384727
# Batch 1600 Loss 0.011030123569071293
# Batch 1700 Loss 0.028627920895814896
# Batch 1800 Loss 0.02876175194978714
# Eppoch 4
# Batch 0 Loss 0.01728641800582409
# Batch 100 Loss 0.015841709449887276
# Batch 200 Loss 0.010958447121083736
# Batch 300 Loss 0.008552012033760548
# Batch 400 Loss 0.0006416841642931104
# Batch 500 Loss 0.0014108361210674047
# Batch 600 Loss 0.04600141569972038
# Batch 700 Loss 0.0027344762347638607
# Batch 800 Loss 0.0016707758186385036
# Batch 900 Loss 0.024968719109892845
# Batch 1000 Loss 0.010207919403910637
# Batch 1100 Loss 0.0005086194723844528
# Batch 1200 Loss 0.002272701123729348
# Batch 1300 Loss 0.0022210623137652874
# Batch 1400 Loss 0.010193729773163795
# Batch 1500 Loss 0.014918772503733635
# Batch 1600 Loss 0.001246603555046022
# Batch 1700 Loss 0.0010854159481823444
# Batch 1800 Loss 0.01161240879446268

# %%
# Out:
# Test Accuracy: 94.6%
